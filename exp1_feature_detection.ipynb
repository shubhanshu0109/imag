# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhanshu0109/imag/blob/main/exp1_feature_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip3 install scikit-image matplotlib
#importing required libraries
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

# %%
# reading the image
img = imread('test.jpeg')
plt.axis("off")
plt.imshow(img)
print(img.shape)
# Out:
# (599, 559, 3)

# %%
# resizing image
resized_img = resize(img, (128*4, 64*4))
plt.axis("off")
plt.imshow(resized_img)
print(resized_img.shape)
# Out:
# (512, 256, 3)

# %%
#creating hog features
fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
cells_per_block=(2, 2), visualize=True, multichannel=True)
plt.axis("off")
plt.imshow(hog_image, cmap="gray")
# Out:
# <ipython-input-6-8a69e7e7f3ff>:2: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),

# %%
# save the images
plt.imsave("resized_img.jpg", resized_img)
plt.imsave("hog_image.jpg", hog_image, cmap="gray")
