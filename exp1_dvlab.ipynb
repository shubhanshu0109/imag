# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhanshu0109/imag/blob/main/exp1_dvlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path = "student_data.csv"
df = pd.read_csv("/content/student_data.csv")

print("Original Dataset:")
print(df.head())

print("\nMissing Values:")
print(df.isnull().sum())


plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

df = df.dropna()

preprocessed_file_path = "preprocessed_student_data.csv"
df.to_csv(preprocessed_file_path, index=False)

print("\nPreprocessed Dataset:")
print(df.head())
# Out:
# Original Dataset:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A   4.0     4  at_home       NaN  ...
# 1     GP   F   17       U     GT3       T   1.0     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T   1.0     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T   4.0     2   health  services  ...
# 4     GP   F   16       U     GT3       T   3.0     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
#
# Missing Values:
# school        1
# sex           0
# ...

# %% [markdown]
# # New Section
